# %% [markdown]
# # Examples
#
# This notebook guides you through how to properly generate examples that can be used for downstream model training. It explains what the input and output is.

# %%
import numpy as np

# %% [markdown]
# Make sure to run `pip install -e .` before running the cell below. This command will make sure `diet4cola` is installed as a module in your current Python/Conda environment.

# %%
from diet4cola.cortex import CortexSpec, Cortex, generate_cortex_example
from diet4cola.utils import plot_2d_array

# %% [markdown]
# ## Cortex Generation

# %% [markdown]
# A cortex can be create relatively easily, by simply providing a new seed.

# %%
seed = 1
cortex_spec = CortexSpec(seed=seed)
cortex: Cortex = generate_cortex_example(cortex_spec)

# %%
plot_2d_array(cortex.data, 'Synthetic Actomyosin Cortex', 'gray', 0, 1)
